# %%
from scipy.stats import spearmanr,pearsonr
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
#Collections Classes

# %%
collections_classes = pd.read_csv("jacoco_common_collections.csv")

# %%
statement_coverage_collection_results = collections_classes["LINE_COVERED"] / (collections_classes["LINE_MISSED"] + collections_classes["LINE_COVERED"])

# %%
branch_coverage_collection_results = collections_classes["BRANCH_COVERED"] / (collections_classes["BRANCH_MISSED"] + collections_classes["BRANCH_COVERED"]+0.00000001)

# %%
cyclomatic_coverage_collection_results = (collections_classes["COMPLEXITY_MISSED"] + collections_classes["COMPLEXITY_COVERED"])

# %%
print(spearmanr(cyclomatic_coverage_collection_results.fillna(0), statement_coverage_collection_results.fillna(0)))
print(pearsonr(cyclomatic_coverage_collection_results.fillna(0), statement_coverage_collection_results.fillna(0)))
# Out:
# SpearmanrResult(correlation=-0.38004496560384177, pvalue=8.371488647322272e-18)
# (-0.0038806222500739904, 0.932704303237358)

# %%
print(spearmanr(cyclomatic_coverage_collection_results.fillna(0), branch_coverage_collection_results.fillna(0)))
print(pearsonr(cyclomatic_coverage_collection_results.fillna(0), branch_coverage_collection_results.fillna(0)))
# Out:
# SpearmanrResult(correlation=0.48158220386639305, pvalue=5.239869035298279e-29)
# (0.26704203512550345, 3.245557726772891e-09)

# %%
cyclomatic_coverage_collection_results_g,statement_coverage_collection_results_g = zip(*sorted(zip(cyclomatic_coverage_collection_results,statement_coverage_collection_results)))
plt.scatter(cyclomatic_coverage_collection_results_g, statement_coverage_collection_results_g)
plt.ylabel("Statement coverage results")
plt.xlabel("Cyclomatic complexity results")
plt.title("Apache Collections: Cyclomatic complexity and Statement coverage")
plt.show()

# %%
cyclomatic_coverage_collection_results_g,branch_coverage_collection_results_g = zip(*sorted(zip(cyclomatic_coverage_collection_results,branch_coverage_collection_results)))
plt.scatter(cyclomatic_coverage_collection_results_g, branch_coverage_collection_results_g)
plt.ylabel("Branch coverage results")
plt.xlabel("Cyclomatic complexity results ")
plt.title("Apache Collections:Cyclomatic complexity and branch coverage ")
plt.show()

# %%
#JFreechart classes

# %%
jfreechart_classes = pd.read_csv("jacoco_jfreechart.csv")

# %%
statement_coverage_jfreechart_results = jfreechart_classes["LINE_COVERED"] / (jfreechart_classes["LINE_MISSED"] + jfreechart_classes["LINE_COVERED"])

# %%
branch_coverage_jfreechart_results = jfreechart_classes["BRANCH_COVERED"] / (jfreechart_classes["BRANCH_MISSED"] + jfreechart_classes["BRANCH_COVERED"]+0.00000001)

# %%
cyclomatic_coverage_jfreechart_results = (jfreechart_classes["COMPLEXITY_MISSED"] + jfreechart_classes["COMPLEXITY_COVERED"])

# %%
print(spearmanr(cyclomatic_coverage_jfreechart_results.fillna(0), statement_coverage_jfreechart_results.fillna(0)))
print(pearsonr(cyclomatic_coverage_jfreechart_results.fillna(0), statement_coverage_jfreechart_results.fillna(0)))
# Out:
# SpearmanrResult(correlation=0.01752009464100977, pvalue=0.6804514950207357)
# (0.07412502108435341, 0.08103128282517806)

# %%
print(spearmanr(cyclomatic_coverage_jfreechart_results.fillna(0), branch_coverage_jfreechart_results.fillna(0)))
print(pearsonr(cyclomatic_coverage_jfreechart_results.fillna(0), branch_coverage_jfreechart_results.fillna(0)))
# Out:
# SpearmanrResult(correlation=0.4044331964569176, pvalue=2.964486411338342e-23)
# (0.18109139667545113, 1.7695205653701668e-05)

# %%
cyclomatic_coverage_jfreechart_results_g,statement_coverage_jfreechart_results_g = zip(*sorted(zip(cyclomatic_coverage_jfreechart_results,statement_coverage_jfreechart_results)))
plt.scatter(cyclomatic_coverage_jfreechart_results_g, statement_coverage_jfreechart_results_g)
plt.ylabel("Statement coverage results")
plt.xlabel("Cyclomatic complexity results")
plt.title("JFreeChart: Cyclomatic complexity and Statement coverage")
plt.show()

# %%
cyclomatic_coverage_jfreechart_results_g,branch_coverage_jfreechart_results_g = zip(*sorted(zip(cyclomatic_coverage_jfreechart_results,branch_coverage_jfreechart_results)))
plt.scatter(cyclomatic_coverage_jfreechart_results_g, branch_coverage_jfreechart_results_g)
plt.ylabel("Branch coverage results")
plt.xlabel("Cyclomatic complexity results ")
plt.title("JFreeChart:Cyclomatic complexity and branch coverage ")
plt.show()

# %%
#Common net classes

# %%
net_classes = pd.read_csv("jacoco_commons_net.csv")

# %%
statement_coverage_net_results = net_classes["LINE_COVERED"] / (net_classes["LINE_MISSED"] + net_classes["LINE_COVERED"])

# %%
branch_coverage_net_results = net_classes["BRANCH_COVERED"] / (net_classes["BRANCH_MISSED"] + net_classes["BRANCH_COVERED"]+0.00000001)

# %%
cyclomatic_coverage_net_results = (net_classes["COMPLEXITY_MISSED"] + net_classes["COMPLEXITY_COVERED"])

# %%
print(spearmanr(cyclomatic_coverage_net_results.fillna(0), statement_coverage_net_results.fillna(0)))
print(pearsonr(cyclomatic_coverage_net_results.fillna(0), statement_coverage_net_results.fillna(0)))
# Out:
# SpearmanrResult(correlation=0.1625026007087031, pvalue=0.020534983807755453)
# (0.058849998215589665, 0.40426475944772755)

# %%
print(spearmanr(cyclomatic_coverage_net_results.fillna(0), branch_coverage_net_results.fillna(0)))
print(pearsonr(cyclomatic_coverage_net_results.fillna(0), branch_coverage_net_results.fillna(0)))
# Out:
# SpearmanrResult(correlation=0.3863536682985543, pvalue=1.2459106800243127e-08)
# (0.14159722435361552, 0.04388824293541655)

# %%
cyclomatic_coverage_net_results_g,statement_coverage_net_results_g = zip(*sorted(zip(cyclomatic_coverage_net_results,statement_coverage_net_results)))
plt.scatter(cyclomatic_coverage_net_results_g, statement_coverage_net_results_g)
plt.ylabel("Statement coverage results")
plt.xlabel("Cyclomatic complexity results")
plt.title("Commons net: Cyclomatic complexity and Statement coverage")
plt.show()

# %%
cyclomatic_coverage_net_results_g,branch_coverage_net_results_g = zip(*sorted(zip(cyclomatic_coverage_net_results,branch_coverage_net_results)))
plt.scatter(cyclomatic_coverage_net_results_g, branch_coverage_net_results_g)
plt.ylabel("Branch coverage results")
plt.xlabel("Cyclomatic complexity results ")
plt.title("Commons net:Cyclomatic complexity and branch coverage ")
plt.show()

# %%
#Common Math

# %%
math_classes = pd.read_csv("jacoco_common_math.csv")

# %%
statement_coverage_math_results = math_classes["LINE_COVERED"] / (math_classes["LINE_MISSED"] + math_classes["LINE_COVERED"])

# %%
cyclomatic_coverage_math_results = (math_classes["COMPLEXITY_MISSED"] + math_classes["COMPLEXITY_COVERED"])

# %%
branch_coverage_math_results = math_classes["BRANCH_COVERED"] / (math_classes["BRANCH_MISSED"] + math_classes["BRANCH_COVERED"]+0.00000001)

# %%
print(spearmanr(cyclomatic_coverage_math_results.fillna(0), statement_coverage_math_results.fillna(0)))
print(pearsonr(cyclomatic_coverage_math_results.fillna(0), statement_coverage_math_results.fillna(0)))
# Out:
# SpearmanrResult(correlation=-0.3594532868601613, pvalue=5.129728460167103e-32)
# (0.04330362862004931, 0.17014588832215832)

# %%
print(spearmanr(cyclomatic_coverage_math_results.fillna(0), branch_coverage_math_results.fillna(0)))
print(pearsonr(cyclomatic_coverage_math_results.fillna(0), branch_coverage_math_results.fillna(0)))
# Out:
# SpearmanrResult(correlation=0.6208739132390855, pvalue=3.6036412731409915e-108)
# (0.3159621813241878, 9.794439461808784e-25)

# %%
cyclomatic_coverage_math_results_g,statement_coverage_math_results_g = zip(*sorted(zip(cyclomatic_coverage_math_results,statement_coverage_math_results)))
plt.scatter(cyclomatic_coverage_math_results_g, statement_coverage_math_results_g)
plt.ylabel("Statement coverage results")
plt.xlabel("Cyclomatic complexity results")
plt.title("Commons math: Cyclomatic complexity and Statement coverage")
plt.show()

# %%
cyclomatic_coverage_math_results_g,branch_coverage_math_results_g = zip(*sorted(zip(cyclomatic_coverage_math_results,branch_coverage_math_results)))
plt.scatter(cyclomatic_coverage_math_results_g, branch_coverage_math_results_g)
plt.ylabel("Branch coverage results")
plt.xlabel("Cyclomatic complexity results ")
plt.title("Commons math:Cyclomatic complexity and branch coverage ")
plt.show()
